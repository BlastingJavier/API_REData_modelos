# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.style.use('science')

# %%
loss1 =np.load( 'arrays_guardados/loss_dense.npy')
loss2 =np.load( 'arrays_guardados/loss_dense_val.npy')
loss3 =np.load('arrays_guardados/densetime2vec_train.npy')
loss4 = np.load('arrays_guardados/densetime2vec_val.npy')

# %%
plt.yscale("log")
plt.plot(loss1, 'b', label="Entrenamiento DNN")
plt.plot(loss3, 'r', label="Entrenamiento DNN+Time2Vec")
plt.plot(loss2, 'g--', label="Validación DNN")
plt.plot(loss4, 'm--', label="Validación DNN+Time2Vec")
plt.legend(loc='best')

plt.xlabel("Épocas")
plt.ylabel("Perdida MSE")
plt.show()

# %%
plt.legend(loc='best')

plt.xlabel("Epochs")
plt.ylabel("Loss MSE")
plt.show()
